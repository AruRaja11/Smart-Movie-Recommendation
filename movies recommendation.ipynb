# %%
import pandas as pd
import numpy as np
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, fpgrowth, association_rules
import re

# %%
url = "https://files.grouplens.org/datasets/movielens/ml-100k/u.data"
movies_url = "https://files.grouplens.org/datasets/movielens/ml-100k/u.item"
ratings = pd.read_csv(url, sep='\t', names=['user_id', 'movie_id', 'rating', 'timestamp'])

# Load movie metadata
movies = pd.read_csv(movies_url, sep='|', encoding='latin-1', header=None, usecols=[0, 1])
movies.columns = ['movie_id', 'title']

# %%
movies
# Out:
#       movie_id                                      title
# 0            1                           Toy Story (1995)
# 1            2                           GoldenEye (1995)
# 2            3                          Four Rooms (1995)
# 3            4                          Get Shorty (1995)
# 4            5                             Copycat (1995)
# ...        ...                                        ...
# 1677      1678                          Mat' i syn (1997)
# 1678      1679                           B. Monkey (1998)
# 1679      1680                       Sliding Doors (1998)
# 1680      1681                        You So Crazy (1994)
# 1681      1682  Scream of Stone (Schrei aus Stein) (1991)
#
# [1682 rows x 2 columns]

# %%
data = pd.merge(movies, ratings, on='movie_id', how='inner')

# %%
data
# Out:
#        movie_id                                      title  user_id  rating  \
# 0             1                           Toy Story (1995)      308       4
# 1             1                           Toy Story (1995)      287       5
# 2             1                           Toy Story (1995)      148       4
# 3             1                           Toy Story (1995)      280       4
# 4             1                           Toy Story (1995)       66       3
# ...         ...                                        ...      ...     ...
# 99995      1678                          Mat' i syn (1997)      863       1
# 99996      1679                           B. Monkey (1998)      863       3
# 99997      1680                       Sliding Doors (1998)      863       2
# 99998      1681                        You So Crazy (1994)      896       3
# 99999      1682  Scream of Stone (Schrei aus Stein) (1991)      916       3
#
#        timestamp
# 0      887736532
# 1      875334088
# 2      877019411
# 3      891700426
# 4      883601324
# ...          ...
# 99995  889289570
# 99996  889289491
# 99997  889289570
# 99998  887160722
# 99999  880845755
#
# [100000 rows x 5 columns]

# %%
data = data[data['rating'] >=3]

# %%
len(data)
# Out:
# 82520

# %%
data = data[['user_id', 'title']]

# %%
def clean_data(row):
    if row == None:
        return None

    row = re.findall(r"[a-zA-Z\s]", row)
    row = "".join(row)
    row = row.strip()
    row = row.lower()
    return row


data['title'] = data['title'].apply(clean_data)

data['title'][0]
# Out:
# 'toy story'

# %%
data.head()
# Out:
#    user_id      title
# 0      308  toy story
# 1      287  toy story
# 2      148  toy story
# 3      280  toy story
# 4       66  toy story

# %%
data[data['user_id'] == 1]
# Out:
#        user_id              title
# 129          1          toy story
# 483          1          goldeneye
# 657          1         four rooms
# 807          1         get shorty
# 927          1            copycat
# ...        ...                ...
# 40715        1            unknown
# 40799        1        chasing amy
# 41061        1     full monty the
# 41321        1            gattaca
# 41645        1  good will hunting
#
# [219 rows x 2 columns]

# %%
data_agg = data.groupby(['user_id'])['title'].unique().agg(list).reset_index()
# Out:
# C:\Users\Ajay\AppData\Local\Temp\ipykernel_20396\446340486.py:1: FutureWarning: using <class 'list'> in Series.agg cannot aggregate and has been deprecated. Use Series.transform to keep behavior unchanged.
#   data_agg = data.groupby(['user_id'])['title'].unique().agg(list).reset_index()

# %%
data_agg
# Out:
#      user_id                                              title
# 0          1  [toy story, goldeneye, four rooms, get shorty,...
# 1          2  [toy story, mighty aphrodite, postino il, anto...
# 2          3  [return of the jedi, event horizon, chasing am...
# 3          4  [seven seen, star wars, indiana jones and the ...
# 4          5  [toy story, goldeneye, from dusk till dawn, mu...
# ..       ...                                                ...
# 938      939  [dead man walking, mr hollands opus, diaboliqu...
# 939      940  [twelve monkeys, babe, dead man walking, usual...
# 940      941  [toy story, twelve monkeys, mr hollands opus, ...
# 941      942  [crimson tide, star wars, lion king the, fugit...
# 942      943  [goldeneye, dead man walking, seven seen, usua...
#
# [943 rows x 2 columns]

# %% [markdown]
# ## Model

# %%
te = TransactionEncoder()

# %%
te_encode = te.fit(data_agg['title']).transform(data_agg['title'])

# %%
enc_data = pd.DataFrame(te_encode, columns=te.columns_)

# %%
enc_data
# Out:
#             a chef in love  a space odyssey  above the rim  absolute power  \
# 0    False           False             True          False           False
# 1    False           False            False          False            True
# 2    False           False            False          False           False
# 3    False           False            False          False           False
# 4    False           False             True          False           False
# ..     ...             ...              ...            ...             ...
# 938  False           False            False          False           False
# 939  False           False            False          False           False
# 940  False           False            False          False           False
# 941  False           False             True          False           False
# 942  False           False            False          False           False
#
#      abyss the  ace ventura pet detective  ace ventura when nature calls  \
# 0         True                       True                          False
# 1        False                      False                          False
# 2        False                      False                          False
# 3        False                      False                          False
# 4        False                      False                          False
# ..         ...                        ...                            ...
# 938      False                      False                          False
# 939      False                      False                          False
# 940      False                      False                          False
# 941      False                      False                          False
# 942      False                       True                          False
#
#      across the sea of time  addams family values  ...  \
# 0                     False                 False  ...
# 1                     False                 False  ...
# 2                     False                 False  ...
# 3                     False                 False  ...
# 4                     False                 False  ...
# ..                      ...                   ...  ...
# 938                   False                 False  ...
# 939                   False                 False  ...
# 940                   False                 False  ...
# 941                   False                 False  ...
# 942                   False                 False  ...
#
#      world of apu the apur sansar  wrong trousers the  wyatt earp  \
# 0                           False                True       False
# 1                           False               False       False
# 2                           False               False       False
# 3                           False               False       False
# 4                           False                True       False
# ..                            ...                 ...         ...
# 938                         False               False       False
# 939                         False               False       False
# 940                         False               False       False
# 941                         False               False       False
# 942                         False               False       False
#
#      year of the horse  you so crazy  young frankenstein  young guns  \
# 0                False         False                True        True
# 1                False         False               False       False
# 2                False         False               False       False
# 3                False         False               False       False
# 4                False         False                True       False
# ..                 ...           ...                 ...         ...
# 938              False         False               False       False
# 939              False         False               False       False
# 940              False         False               False       False
# 941              False         False               False       False
# 942              False         False               False        True
#
#      young guns ii  young poisoners handbook the  zeus and roxanne
# 0            False                         False             False
# 1            False                         False             False
# 2            False                         False             False
# 3            False                         False             False
# 4            False                         False             False
# ..             ...                           ...               ...
# 938          False                         False             False
# 939          False                         False             False
# 940          False                         False             False
# 941          False                         False             False
# 942           True                         False             False
#
# [943 rows x 1545 columns]

# %%
model = apriori(enc_data, min_support=0.20, use_colnames=True)

# %%
result_df = association_rules(model)[['antecedents', 'consequents', 'confidence']]

# %%
result_df['antecedents'] = result_df['antecedents'].apply(lambda x: ', '.join(map(str, x)))
result_df['consequents'] = result_df['consequents'].apply(lambda x: ', '.join(map(str, x)))

# %%
result_df
# Out:
#                                            antecedents  \
# 0                                      a space odyssey
# 1                                      a space odyssey
# 2                                               aliens
# 3                                                alien
# 4                                                alien
# ..                                                 ...
# 939  terminator the, raiders of the lost ark, retur...
# 940      star wars, terminator the, return of the jedi
# 941  terminator the, raiders of the lost ark, star ...
# 942            terminator the, empire strikes back the
# 943                 terminator the, return of the jedi
#
#                                            consequents  confidence
# 0                              raiders of the lost ark    0.841880
# 1                                            star wars    0.846154
# 2                                                alien    0.820611
# 3                              raiders of the lost ark    0.840426
# 4                             silence of the lambs the    0.804965
# ..                                                 ...         ...
# 939                 empire strikes back the, star wars    0.920561
# 940   empire strikes back the, raiders of the lost ark    0.875556
# 941        empire strikes back the, return of the jedi    0.841880
# 942  star wars, raiders of the lost ark, return of ...    0.856522
# 943  empire strikes back the, raiders of the lost a...    0.864035
#
# [944 rows x 3 columns]

# %%
user = "aliens"

for i in range(len(result_df)):
    if user == result_df['antecedents'][i]:
        print(result_df['consequents'][i])
    else:
        continue
# Out:
# alien
# raiders of the lost ark
# silence of the lambs the
# star wars
# raiders of the lost ark, star wars

# %%
result_df.to_csv('movies_recommendation.csv')
